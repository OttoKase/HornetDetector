# %% [markdown]
# # Downloading from metadata and directly uploading to Roboflow

# %% [markdown]
# ### Step 1: Install and import

# %%
#!pip install roboflow
import csv
import requests
import time
import tempfile
import os
import random
from io import BytesIO
from roboflow import Roboflow
from google.colab import drive
from concurrent.futures import ThreadPoolExecutor, as_completed

# %% [markdown]
# ### Step 2: Mount Google Drive in Colab

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Step 3: Configuration

# %%
METADATA_FILE = "/content/drive/MyDrive/hornet_project/data/metadata/hornets_metadata.csv"

ROBOFLOW_API_KEY = "Tlb27HVkFzyExjB3VkA5"
WORKSPACE_ID = "hornets-kfaxc"
PROJECT_ID = "project-hornet-detection-bbpor"
BATCH_NAME = "hornet_upload_batch"

# License types to allow
ALLOWED_LICENSES = {
    "cc0",
    "by/4.0", "by/3.0", "by/2.5", "by/2.0",
    "by-sa/4.0", "by-sa/3.0", "by-sa/2.5",
    "by-nc/4.0", "by-nc/3.0", "by-nc/2.5",
    "by-nc-sa/4.0", "by-nc-sa/3.0", "by-nc-sa/2.5",
}

# %% [markdown]
# ### Step 4: Define functions

# %%
# ==================================================
# DATA LOADING AND FILTERING
# ==================================================
def load_metadata(csv_file):
    """Load GBIF Darwin Core metadata file."""
    try:
        with open(csv_file, 'r', encoding='utf-8') as f:
            reader = csv.DictReader(f, delimiter='\t')
            records = list(reader)
        print(f"Loaded {len(records)} records from {csv_file}")
        return records
    except FileNotFoundError:
        print(f"❌ Error: {csv_file} not found.")
        return []

def filter_by_license(records):
    """Keep only records with permissive licenses."""
    filtered = []
    for r in records:
        license_url = r.get('license', '').lower()
        is_allowed = any(p in license_url for p in ALLOWED_LICENSES)
        if is_allowed or license_url == '':
            filtered.append(r)
    print(f"Filtered to {len(filtered)} permissively licensed records")
    return filtered

def get_image_url(record):
    return record.get('identifier', '').strip()

# ==================================================
# ROBOFLOW UPLOAD
# ==================================================
def init_roboflow():
    print("\nConnecting to Roboflow...")
    rf = Roboflow(api_key=ROBOFLOW_API_KEY)
    project = rf.workspace(WORKSPACE_ID).project(PROJECT_ID)
    print(f"✅ Connected to: {WORKSPACE_ID}/{PROJECT_ID}")
    return project

def upload_image_from_url(project, url, idx, total):
    """Download image from URL, save temporarily, upload, and delete."""
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()

        # Create a temporary file (auto-deleted after upload)
        with tempfile.NamedTemporaryFile(suffix=".jpg", delete=False) as tmp:
            tmp.write(response.content)
            tmp.flush()
            tmp_path = tmp.name

        # Upload from the temporary file
        project.upload(
            image_path=tmp_path,
            batch_name=BATCH_NAME,
            split="train",
            num_retry_uploads=3,
            tag_names=["hornet"],
            sequence_number=idx,
            sequence_size=total
        )

        os.remove(tmp_path)
        print(f"✅ [{idx}/{total}] Uploaded: {url[:60]}...")
        return True

    except requests.exceptions.RequestException as e:
        print(f"⚠️ [{idx}/{total}] Download failed: {e}")
        return False
    except Exception as e:
        print(f"⚠️ [{idx}/{total}] Upload failed: {e}")
        return False

# %% [markdown]
# ### Step 5: Download and upload

# %%
# ==================================================
# MAIN
# ==================================================

def main(n=100, start_index=0, randomize=False):
    print("GBIF Hornet Downloader → Roboflow Uploader (parallel, no local save)")
    print("=" * 70)

    records = load_metadata(METADATA_FILE)
    if not records:
        return

    records = filter_by_license(records)
    project = init_roboflow()

    total = min(n, len(records))
    # Collect image URLs from filtered records
    urls = [get_image_url(r) for r in records[start_index:] if get_image_url(r)]

    # Shuffle if requested
    if randomize:
        random.shuffle(urls)

    # Take only n images if n is set
    if n is not None:
        urls = urls[:n]

    uploaded = 0
    failed = 0

    # Control how many threads (5–10 is usually safe)
    MAX_WORKERS = 5

    print(f"Starting parallel upload of {len(urls)} images using {MAX_WORKERS} threads...\n")

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = {
            executor.submit(upload_image_from_url, project, url, idx + 1, total): url
            for idx, url in enumerate(urls)
        }

        for future in as_completed(futures):
            try:
                if future.result():
                    uploaded += 1
                else:
                    failed += 1
            except Exception as e:
                print(f"⚠️ Unexpected error: {e}")
                failed += 1

    print("\n" + "=" * 70)
    print(f"✅ Upload complete!")
    print(f"Uploaded: {uploaded}")
    print(f"Failed: {failed}")
    print(f"Total processed: {uploaded + failed}")

# %% [markdown]
# ### Step 6: Run the functions

# %%
image_count = 100

main(n = 200, start_index = 100, randomize=True)
# Out:
# GBIF Hornet Downloader → Roboflow Uploader (parallel, no local save)
# ======================================================================
# Loaded 167847 records from /content/drive/MyDrive/hornet_project/data/metadata/hornets_metadata.csv
# Filtered to 76384 permissively licensed records
#
# Connecting to Roboflow...
# loading Roboflow workspace...
# loading Roboflow project...
# ✅ Connected to: hornets-kfaxc/project-hornet-detection-bbpor
# Starting parallel upload of 200 images using 5 threads...
#
# ✅ [4/200] Uploaded: https://observation.org/photos/56491045.jpg...
# ✅ [3/200] Uploaded: https://observation.org/photos/17101872.jpg...
# ✅ [2/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/247521...
# ✅ [1/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/326041...
# ✅ [5/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/474445...
# ✅ [7/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/113635...
# ✅ [6/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/554310...
# ✅ [10/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/168495...
# ✅ [8/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/228678...
# ✅ [12/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/448434...
# ✅ [9/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/581969...
# ✅ [11/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/383409...
# ✅ [13/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/318283...
# ✅ [15/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/159119...
# ✅ [17/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/443250...
# ✅ [14/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/157339...
# ✅ [18/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/582930...
# ✅ [16/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/368580...
# ✅ [21/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/515694...
# ✅ [19/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/435958...
# ✅ [20/200] Uploaded: https://observation.org/photos/11743354.jpg...
# ✅ [22/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/545396...
# ✅ [23/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/210903...
# ✅ [24/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/449708...
# ✅ [25/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/380236...
# ✅ [26/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/329686...
# ✅ [28/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/469484...
# ✅ [27/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/573762...
# ✅ [29/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/135949...
# ✅ [31/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/518722...
# ✅ [30/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/362064...
# ✅ [32/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos
200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/325810...
# ✅ [118/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/441192...
# ✅ [122/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/376166...
# ✅ [124/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/564534...
# ✅ [125/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/324177...
# ✅ [123/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/261513...
# ✅ [127/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/883367...
# ✅ [126/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/101543...
# ✅ [121/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/262496...
# ✅ [128/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/151879...
# ✅ [129/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/463922...
# ✅ [130/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/569077...
# ✅ [134/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/384538...
# ✅ [132/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/580662...
# ✅ [131/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/192453...
# ✅ [133/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/292048...
# ✅ [135/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/312358...
# ✅ [136/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/401031...
# ✅ [138/200] Uploaded: https://observation.org/photos/9477587.jpg...
# ✅ [141/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/496641...
# ✅ [137/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/516781...
# ✅ [142/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/581882...
# ✅ [143/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/506017...
# ✅ [139/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/557710...
# ✅ [140/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/549364...
# ✅ [145/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/406999...
# ✅ [149/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/378999...
# ✅ [146/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/239064...
# ✅ [147/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/729696...
# ✅ [150/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/159316...
# ✅ [148/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/311596...
# ✅ [151/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/153095...
# ✅ [152/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/930914...
# ✅ [153/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/318473...
# ✅ [154/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/573493...
# ✅ [155/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/563001...
# ✅ [156/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/563890...
# ✅ [158/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/804270...
# ✅ [157/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/325469...
# ✅ [159/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/340497...
# ✅ [160/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/162400...
# ✅ [163/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/132933...
# ✅ [161/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/150505...
# ✅ [162/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/204923...
# ✅ [164/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/562280...
# ⚠️ [144/200] Download failed: HTTPSConnectionPool(host='inpn.mnhn.fr', port=443): Max retries exceeded with url: /inpn-especes/photos/original/684475.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x79d5a1cdaae0>, 'Connection to inpn.mnhn.fr timed out. (connect timeout=10)'))
# ✅ [167/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/131049...
# ✅ [168/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/202668...
# ✅ [166/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/161809...
# ✅ [165/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/179922...
# ✅ [170/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/556693...
# ✅ [169/200] Uploaded: https://www.artsobservasjoner.no/MediaLibrary/2025/6/93d7862...
# ✅ [171/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/626005...
# ✅ [175/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/422501...
# ✅ [172/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/319912...
# ✅ [173/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/545747...
# ✅ [176/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/552745...
# ✅ [174/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/557489...
# ✅ [177/200] Uploaded: https://observation.org/photos/96632392.jpg...
# ✅ [179/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/179932...
# ✅ [181/200] Uploaded: https://observation.org/photos/56141293.jpg...
# ✅ [178/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/507739...
# ✅ [184/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/521407...
# ✅ [182/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/320314...
# ✅ [183/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/380976...
# ✅ [185/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/294632...
# ✅ [186/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/441561...
# ✅ [189/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/489686...
# ✅ [188/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/194520...
# ✅ [187/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/284297...
# ✅ [180/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/559796...
# ✅ [193/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/200257...
# ✅ [191/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/553092...
# ✅ [192/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/237598...
# ✅ [194/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/102792...
# ✅ [190/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/513370...
# ✅ [195/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/379336...
# ✅ [196/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/551587...
# ✅ [197/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/425351...
# ✅ [198/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/548914...
# ✅ [199/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/128922...
# ✅ [200/200] Uploaded: https://inaturalist-open-data.s3.amazonaws.com/photos/424077...
#
# ======================================================================
# ✅ Upload complete!
# Uploaded: 199
# Failed: 1
# Total processed: 200
